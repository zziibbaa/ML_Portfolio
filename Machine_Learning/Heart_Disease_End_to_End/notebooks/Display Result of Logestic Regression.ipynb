# %%
from main_logestic import main
main()
# Out:
# best threshold is: 0.46733668341708545
# Test F1-score: 0.929
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        17
#            1       0.93      0.93      0.93        14
#
#     accuracy                           0.94        31
#    macro avg       0.93      0.93      0.93        31
# weighted avg       0.94      0.94      0.94        31
# ========== FINAL RESULTS ==========
# Best Threshold : 0.470
# Test F1 Score  : 0.930
# ROC-AUC        : 0.980
